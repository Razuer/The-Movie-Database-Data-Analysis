# %%
import requests
import time, csv, math

# %% [markdown]
# Słowem wstępu - zgodnie z regulaminem i warunkami korzystania z usługi, niniejszy raport został opracowany przy użyciu Klucza API udostępnionego przez The Movie Database (TMDB). Klucz API jest niezbędny do uzyskania dostępu do danych filmowych i analizy przeprowadzonej w ramach tego projektu.
#
# Klucz API został otrzymany poprzez proces rejestracji i wnioskowania na stronie TMDB, zgodnie z wytycznymi udostępnionymi przez dostawcę usługi. Wniosek został złożony i zatwierdzony, a Klucz API został przypisany do tego projektu, umożliwiając dostęp do niezbędnych danych filmowych.
#
# Wszelkie analizy, wyniki i prezentowane dane będą w tym raporcie oparte na danych udostępnionych przez TMDB przy użyciu Klucza API i zgodnie z dostępem, który mi został przyznany.

# %% [markdown]
# Wykorzystam poniższy skrypt, który napisałem, do uzyskania najpierw wszystkich numerów ID wybranej przeze mnie liczby filmów. Do mojego projektu, myślę, że wystarczy mi ich 10000, zatem właśnie tyle ich pobiorę.
#
# *W parametrach jest pole **"api_key"**, którego wartość zakryłem, bez niego **nie uda się** pobrać danych filmowych.*

# %%
# Ustawienie parametrów wyszukiwania
base_url = "https://api.themoviedb.org/3"
endpoint = "/discover/movie"
params = {
    "api_key": "MY_API_KEY",
    "sort_by": "popularity.desc",
    "page": 1,
}

# Pobranie danych dla n filmów
n = 10000
total_pages = math.ceil(n / 20)
print(
    total_pages
)  # Zgodnie z dokumentacją TMDB na jednej stronie znajduje się 20 filmów

movies_ids = []
errors_in_a_row = 0
for i in range(1, total_pages + 1):
    params["page"] = i
    print(f"Retrieving page {i}/{total_pages}")
    url = f"{base_url}{endpoint}"
    response = requests.get(url, params=params)
    if response.status_code == 200:
        errors_in_a_row = 0
        data = response.json()
        if data["results"]:
            for movie in data["results"]:
                movies_ids.append(movie["id"])
                if len(movies_ids) >= n:
                    break
        if len(movies_ids) >= n:
            break

    elif response.status_code == 429:
        retry_after = int(response.headers.get("Retry-After"))
        print(f"Query limit exceeded. Wait for {retry_after} seconds...")
        time.sleep(retry_after)
        i -= 1
    else:
        print(
            f"An error was encountered while fetching data from page {i}. Status code = {response.status_code}"
        )
        errors_in_a_row += 1
        if errors_in_a_row > 30:
            break

    if i % 10 == 0:
        wait_time = 2
        print(
            f"Waiting for {wait_time} seconds... There are currently {len(movies_ids)} movies IDs saved."
        )
        time.sleep(wait_time)
# Out:
# 1000
# Retrieving page 1/1000
# Retrieving page 2/1000
# Retrieving page 3/1000
# Retrieving page 4/1000
# Retrieving page 5/1000
# Retrieving page 6/1000
# Retrieving page 7/1000
# Retrieving page 8/1000
# Retrieving page 9/1000
# Retrieving page 10/1000
# Waiting for 2 seconds... There are currently 200 movies IDs saved.
# Retrieving page 11/1000
# Retrieving page 12/1000
# Retrieving page 13/1000
# Retrieving page 14/1000
# Retrieving page 15/1000
# Retrieving page 16/1000
# Retrieving page 17/1000
# Retrieving page 18/1000
# Retrieving page 19/1000
# Retrieving page 20/1000
# Waiting for 2 seconds... There are currently 400 movies IDs saved.
# Retrieving page 21/1000
# Retrieving page 22/1000
# Retrieving page 23/1000
# Retrieving page 24/1000
# Retrieving page 25/1000
# Retrieving page 26/1000
# Retrieving page 27/1000
# Retrieving page 28/1000
# Retrieving page 29/1000
# Retrieving page 30/1000
# Waiting for 2 seconds... There are currently 600 movies IDs saved.
# Retrieving page 31/1000
# Retrieving page 32/1000
# Retrieving page 33/1000
# Retrieving page 34/1000
# Retrieving page 35/1000
# Retrieving page 36/1000
# Retrieving page 37/1000
# Retrieving page 38/1000
# Retrieving page 39/1000
# Retrieving page 40/1000
# Waiting for 2 seconds... There are currently 800 movies IDs saved.
# Retrieving page 41/1000
# Retrieving page 42/1000
# Retrieving page 43/1000
# Retrieving page 44/1000
# Retrieving page 45/1000
# Retrieving page 46/1000
# Retrieving page 47/1000
# Retrieving page 48/1000
# Retrieving page 49/1000
# Retrieving page 50/1000
# Waiting for 2 seconds... There are currently 1000 movies IDs saved.
# Retrieving page 51/1000
# Retrieving page 52/1000
# Retrieving page 53/1000
# Retrieving page 54/1000
# Retrieving page 55/1000
# Retrieving page 56/1000
# Retrieving page 57/1000
# Retrieving page 58/1000
# Retrieving page 59/1000
# Retrieving page 60/1000
# Waiting for 2 seconds... There are currently 1200 movies IDs saved.
# Retrieving page 61/1000
# Retrieving page 62/1000
# Retrieving page 63/1000
# Retrieving page 64/1000
# Retrieving page 65/1000
# Retrieving page 66/1000
# Retrieving page 67/1000
# Retrieving page 68/1000
# Retrieving page 69/1000
# Retrieving page 70/1000
# Waiting for 2 seconds... There are currently 1400 movies IDs saved.
# Retrieving page 71/1000
# Retrieving page 72/1000
# Retrieving page 73/1000
# Retrieving page 74/1000
# Retrieving page 75/1000
# Retrieving page 76/1000
# Retrieving page 77/1000
# Retrieving page 78/1000
# Retrieving page 79/1000
# Retrieving page 80/1000
# Waiting for 2 seconds... There are currently 1600 movies IDs saved.
# Retrieving page 81/1000
# Retrieving page 82/1000
# Retrieving page 83/1000
# Retrieving page 84/1000
# Retrieving page 85/1000
# Retrieving page 86/1000
# Retrieving page 87/1000
# Retrieving page 88/1000
# Retrieving page 89/1000
# Retrieving page 90/1000
# Waiting for 2 seconds... There are currently 1800 movies IDs saved.
# Retrieving page 91/1000
# Retrieving page 92/1000
# Retrieving page 93/1000
# Retrieving page 94/1000
# Retrieving page 95/1000
# Retrieving page 96/1000
# Retrieving page 97/1000
# Retrieving page 98/1000
# Retrieving page 99/1000
# Retrieving page 100/1000
# Waiting for 2 seconds... There are currently 2000 movies IDs saved.
# Retrieving page 101/1000
# Retrieving page 102/1000
# Retrieving page 103/1000
# Retrieving page 104/1000
# Retrieving page 105/1000
# Retrieving page 106/1000
# Retrieving page 107/1000
# Retrieving page 108/1000
# Retrieving page 109/1000
# Retrieving page 110/1000
# Waiting for 2 seconds... There are currently 2200 movies IDs saved.
# Retrieving page 111/1000
# Retrieving page 112/1000
# Retrieving page 113/1000
# Retrieving page 114/1000
# Retrieving page 115/1000
# Retrieving page 116/1000
# Retrieving page 117/1000
# Retrieving page 118/1000
# Retrieving page 119/1000
# Retrieving page 120/1000
# Waiting for 2 seconds... There are currently 2400 movies IDs saved.
# Retrieving page 121/1000
# Retrieving page 122/1000
# Retrieving page 123/1000
# Retrieving page 124/1000
# Retrieving page 125/1000
# Retrieving page 126/1000
# Retrieving page 127/1000
# Retrieving page 128/1000
# Retrieving page 129/1000
# Retrieving page 130/1000
# Waiting for 2 seconds... There are currently 2600 movies IDs saved.
# Retrieving page 131/1000
# Retrieving page 132/1000
# Retrieving page 133/1000
# Retrieving page 134/1000
# Retrieving page 135/1000
# Retrieving page 136/1000
# Retrieving page 137/1000
# Retrieving page 138/1000
# Retrieving page 139/1000
# Retrieving page 140/1000
# Waiting for 2 seconds... There are currently 2800 movies IDs saved.
# Retrieving page 141/1000
# Retrieving page 142/1000
# Retrieving page 143/1000
# Retrieving page 144/1000
# Retrieving page 145/1000
# Retrieving page 146/1000
# Retrieving page 147/1000
# Retrieving page 148/1000
# Retrieving page 149/1000
# Retrieving page 150/1000
# Waiting for 2 seconds... There are currently 3000 movies IDs saved.
# Retrieving page 151/1000
# Retrieving page 152/1000
# Retrieving page 153/1000
# Retrieving page 154/1000
# Retrieving page 155/1000
# Retrieving page 156/1000
# Retrieving page 157/1000
# Retrieving page 158/1000
# Retrieving page 159/1000
# Retrieving page 160/1000
# Waiting for 2 seconds... There are currently 3200 movies IDs saved.
# Retrieving page 161/1000
# Retrieving page 162/1000
# Retrieving page 163/1000
# Retrieving page 164/1000
# Retrieving page 165/1000
# Retrieving page 166/1000
# Retrieving page 167/1000
# Retrieving page 168/1000
# Retrieving page 169/1000
# Retrieving page 170/1000
# Waiting for 2 seconds... There are currently 3400 movies IDs saved.
# Retrieving page 171/1000
# Retrieving page 172/1000
# Retrieving page 173/1000
# Retrieving page 174/1000
# Retrieving page 175/1000
# Retrieving page 176/1000
# Retrieving page 177/1000
# Retrieving page 178/1000
# Retrieving page 179/1000
# Retrieving page 180/1000
# Waiting for 2 seconds... There are currently 3600 movies IDs saved.
# Retrieving page 181/1000
# Retrieving page 182/1000
# Retrieving page 183/1000
# Retrieving page 184/1000
# Retrieving page 185/1000
# Retrieving page 186/1000
# Retrieving page 187/1000
# Retrieving page 188/1000
# Retrieving page 189/1000
# Retrieving page 190/1000
# Waiting for 2 seconds... There are currently 3800 movies IDs saved.
# Retrieving page 191/1000
# Retrieving page 192/1000
# Retrieving page 193/1000
# Retrieving page 194/1000
# Retrieving page 195/1000
# Retrieving page 196/1000
# Retrieving page 197/1000
# Retrieving page 198/1000
# Retrieving page 199/1000
# Retrieving page 200/1000
# Waiting for 2 seconds... There are currently 4000 movies IDs saved.
# Retrieving page 201/1000
# Retrieving page 202/1000
# Retrieving page 203/1000
# Retrieving page 204/1000
# Retrieving page 205/1000
# Retrieving page 206/1000
# Retrieving page 207/1000
# Retrieving page 208/1000
# Retrieving page 209/1000
# Retrieving page 210/1000
# Waiting for 2 seconds... There are currently 4200 movies IDs saved.
# Retrieving page 211/1000
# Retrieving page 212/1000
# Retrieving page 213/1000
# Retrieving page 214/1000
# Retrieving page 215/1000
# Retrieving page 216/1000
# Retrieving page 217/1000
# Retrieving page 218/1000
# Retrieving page 219/1000
# Retrieving page 220/1000
# Waiting for 2 seconds... There are currently 4400 movies IDs saved.
# Retrieving page 221/1000
# Retrieving page 222/1000
# Retrieving page 223/1000
# Retrieving page 224/1000
# Retrieving page 225/1000
# Retrieving page 226/1000
# Retrieving page 227/1000
# Retrieving page 228/1000
# Retrieving page 229/1000
# Retrieving page 230/1000
# Waiting for 2 seconds... There are currently 4600 movies IDs saved.
# Retrieving page 231/1000
# Retrieving page 232/1000
# Retrieving page 233/1000
# Retrieving page 234/1000
# Retrieving page 235/1000
# Retrieving page 236/1000
# Retrieving page 237/1000
# Retrieving page 238/1000
# Retrieving page 239/1000
# Retrieving page 240/1000
# Waiting for 2 seconds... There are currently 4800 movies IDs saved.
# Retrieving page 241/1000
# Retrieving page 242/1000
# Retrieving page 243/1000
# Retrieving page 244/1000
# Retrieving page 245/1000
# Retrieving page 246/1000
# Retrieving page 247/1000
# Retrieving page 248/1000
# Retrieving page 249/1000
# Retrieving page 250/1000
# Waiting for 2 seconds... There are currently 5000 movies IDs saved.
# Retrieving page 251/1000
# Retrieving page 252/1000
# Retrieving page 253/1000
# Retrieving page 254/1000
# Retrieving page 255/1000
# Retrieving page 256/1000
# Retrieving page 257/1000
# Retrieving page 258/1000
# Retrieving page 259/1000
# Retrieving page 260/1000
# Waiting for 2 seconds... There are currently 5200 movies IDs saved.
# Retrieving page 261/1000
# Retrieving page 262/1000
# Retrieving page 263/1000
# Retrieving page 264/1000
# Retrieving page 265/1000
# Retrieving page 266/1000
# Retrieving page 267/1000
# Retrieving page 268/1000
# Retrieving page 269/1000
# Retrieving page 270/1000
# Waiting for 2 seconds... There are currently 5400 movies IDs saved.
# Retrieving page 271/1000
# Retrieving page 272/1000
# Retrieving page 273/1000
# Retrieving page 274/1000
# Retrieving page 275/1000
# Retrieving page 276/1000
# Retrieving page 277/1000
# Retrieving page 278/1000
# Retrieving page 279/1000
# Retrieving page 280/1000
# Waiting for 2 seconds... There are currently 5600 movies IDs saved.
# Retrieving page 281/1000
# Retrieving page 282/1000
# Retrieving page 283/1000
# Retrieving page 284/1000
# Retrieving page 285/1000
# Retrieving page 286/1000
# Retrieving page 287/1000
# Retrieving page 288/1000
# Retrieving page 289/1000
# Retrieving page 290/1000
# Waiting for 2 seconds... There are currently 5800 movies IDs saved.
# Retrieving page 291/1000
# Retrieving page 292/1000
# Retrieving page 293/1000
# Retrieving page 294/1000
# Retrieving page 295/1000
# Retrieving page 296/1000
# Retrieving page 297/1000
# Retrieving page 298/1000
# Retrieving page 299/1000
# Retrieving page 300/1000
# Waiting for 2 seconds... There are currently 6000 movies IDs saved.
# Retrieving page 301/1000
# Retrieving page 302/1000
# Retrieving page 303/1000
# Retrieving page 304/1000
# Retrieving page 305/1000
# Retrieving page 306/1000
# Retrieving page 307/1000
# Retrieving page 308/1000
# Retrieving page 309/1000
# Retrieving page 310/1000
# Waiting for 2 seconds... There are currently 6200 movies IDs saved.
# Retrieving page 311/1000
# Retrieving page 312/1000
# Retrieving page 313/1000
# Retrieving page 314/1000
# Retrieving page 315/1000
# Retrieving page 316/1000
# Retrieving page 317/1000
# Retrieving page 318/1000
# Retrieving page 319/1000
# Retrieving page 320/1000
# Waiting for 2 seconds... There are currently 6400 movies IDs saved.
# Retrieving page 321/1000
# Retrieving page 322/1000
# Retrieving page 323/1000
# Retrieving page 324/1000
# Retrieving page 325/1000
# Retrieving page 326/1000
# Retrieving page 327/1000
# Retrieving page 328/1000
# Retrieving page 329/1000
# Retrieving page 330/1000
# Waiting for 2 seconds... There are currently 6600 movies IDs saved.
# Retrieving page 331/1000
# Retrieving page 332/1000
# Retrieving page 333/1000
# Retrieving page 334/1000
# Retrieving page 335/1000
# Retrieving page 336/1000
# Retrieving page 337/1000
# Retrieving page 338/1000
# Retrieving page 339/1000
# Retrieving page 340/1000
# Waiting for 2 seconds... There are currently 6800 movies IDs saved.
# Retrieving page 341/1000
# Retrieving page 342/1000
# Retrieving page 343/1000
# Retrieving page 344/1000
# Retrieving page 345/1000
# Retrieving page 346/1000
# Retrieving page 347/1000
# Retrieving page 348/1000
# Retrieving page 349/1000
# Retrieving page 350/1000
# Waiting for 2 seconds... There are currently 7000 movies IDs saved.
# Retrieving page 351/1000
# Retrieving page 352/1000
# Retrieving page 353/1000
# Retrieving page 354/1000
# Retrieving page 355/1000
# Retrieving page 356/1000
# Retrieving page 357/1000
# Retrieving page 358/1000
# Retrieving page 359/1000
# Retrieving page 360/1000
# Waiting for 2 seconds... There are currently 7200 movies IDs saved.
# Retrieving page 361/1000
# Retrieving page 362/1000
# Retrieving page 363/1000
# Retrieving page 364/1000
# Retrieving page 365/1000
# Retrieving page 366/1000
# Retrieving page 367/1000
# Retrieving page 368/1000
# Retrieving page 369/1000
# Retrieving page 370/1000
# Waiting for 2 seconds... There are currently 7400 movies IDs saved.
# Retrieving page 371/1000
# Retrieving page 372/1000
# Retrieving page 373/1000
# Retrieving page 374/1000
# Retrieving page 375/1000
# Retrieving page 376/1000
# Retrieving page 377/1000
# Retrieving page 378/1000
# Retrieving page 379/1000
# Retrieving page 380/1000
# Waiting for 2 seconds... There are currently 7600 movies IDs saved.
# Retrieving page 381/1000
# Retrieving page 382/1000
# Retrieving page 383/1000
# Retrieving page 384/1000
# Retrieving page 385/1000
# Retrieving page 386/1000
# Retrieving page 387/1000
# Retrieving page 388/1000
# Retrieving page 389/1000
# Retrieving page 390/1000
# Waiting for 2 seconds... There are currently 7800 movies IDs saved.
# Retrieving page 391/1000
# Retrieving page 392/1000
# Retrieving page 393/1000
# Retrieving page 394/1000
# Retrieving page 395/1000
# Retrieving page 396/1000
# Retrieving page 397/1000
# Retrieving page 398/1000
# Retrieving page 399/1000
# Retrieving page 400/1000
# Waiting for 2 seconds... There are currently 8000 movies IDs saved.
# Retrieving page 401/1000
# Retrieving page 402/1000
# Retrieving page 403/1000
# Retrieving page 404/1000
# Retrieving page 405/1000
# Retrieving page 406/1000
# Retrieving page 407/1000
# Retrieving page 408/1000
# Retrieving page 409/1000
# Retrieving page 410/1000
# Waiting for 2 seconds... There are currently 8200 movies IDs saved.
# Retrieving page 411/1000
# Retrieving page 412/1000
# Retrieving page 413/1000
# Retrieving page 414/1000
# Retrieving page 415/1000
# Retrieving page 416/1000
# Retrieving page 417/1000
# Retrieving page 418/1000
# Retrieving page 419/1000
# Retrieving page 420/1000
# Waiting for 2 seconds... There are currently 8400 movies IDs saved.
# Retrieving page 421/1000
# Retrieving page 422/1000
# Retrieving page 423/1000
# Retrieving page 424/1000
# Retrieving page 425/1000
# Retrieving page 426/1000
# Retrieving page 427/1000
# Retrieving page 428/1000
# Retrieving page 429/1000
# Retrieving page 430/1000
# Waiting for 2 seconds... There are currently 8600 movies IDs saved.
# Retrieving page 431/1000
# Retrieving page 432/1000
# Retrieving page 433/1000
# Retrieving page 434/1000
# Retrieving page 435/1000
# Retrieving page 436/1000
# Retrieving page 437/1000
# Retrieving page 438/1000
# Retrieving page 439/1000
# Retrieving page 440/1000
# Waiting for 2 seconds... There are currently 8800 movies IDs saved.
# Retrieving page 441/1000
# Retrieving page 442/1000
# Retrieving page 443/1000
# Retrieving page 444/1000
# Retrieving page 445/1000
# Retrieving page 446/1000
# Retrieving page 447/1000
# Retrieving page 448/1000
# Retrieving page 449/1000
# Retrieving page 450/1000
# Waiting for 2 seconds... There are currently 9000 movies IDs saved.
# Retrieving page 451/1000
# Retrieving page 452/1000
# Retrieving page 453/1000
# Retrieving page 454/1000
# Retrieving page 455/1000
# Retrieving page 456/1000
# Retrieving page 457/1000
# Retrieving page 458/1000
# Retrieving page 459/1000
# Retrieving page 460/1000
# Waiting for 2 seconds... There are currently 9200 movies IDs saved.
# Retrieving page 461/1000
# Retrieving page 462/1000
# Retrieving page 463/1000
# Retrieving page 464/1000
# Retrieving page 465/1000
# Retrieving page 466/1000
# Retrieving page 467/1000
# Retrieving page 468/1000
# Retrieving page 469/1000
# Retrieving page 470/1000
# Waiting for 2 seconds... There are currently 9400 movies IDs saved.
# Retrieving page 471/1000
# Retrieving page 472/1000
# Retrieving page 473/1000
# Retrieving page 474/1000
# Retrieving page 475/1000
# Retrieving page 476/1000
# Retrieving page 477/1000
# Retrieving page 478/1000
# Retrieving page 479/1000
# Retrieving page 480/1000
# Waiting for 2 seconds... There are currently 9600 movies IDs saved.
# Retrieving page 481/1000
# Retrieving page 482/1000
# Retrieving page 483/1000
# Retrieving page 484/1000
# Retrieving page 485/1000
# Retrieving page 486/1000
# Retrieving page 487/1000
# Retrieving page 488/1000
# Retrieving page 489/1000
# Retrieving page 490/1000
# Waiting for 2 seconds... There are currently 9800 movies IDs saved.
# Retrieving page 491/1000
# Retrieving page 492/1000
# Retrieving page 493/1000
# Retrieving page 494/1000
# Retrieving page 495/1000
# Retrieving page 496/1000
# Retrieving page 497/1000
# Retrieving page 498/1000
# Retrieving page 499/1000
# Retrieving page 500/1000
# Waiting for 2 seconds... There are currently 10000 movies IDs saved.
# Retrieving page 501/1000
# An error was encountered while fetching data from page 501. Status code = 422
# Retrieving page 502/1000
# An error was encountered while fetching data from page 502. Status code = 422
# Retrieving page 503/1000
# An error was encountered while fetching data from page 503. Status code = 422
# Retrieving page 504/1000
# An error was encountered while fetching data from page 504. Status code = 422
# Retrieving page 505/1000
# An error was encountered while fetching data from page 505. Status code = 422
# Retrieving page 506/1000
# An error was encountered while fetching data from page 506. Status code = 422
# Retrieving page 507/1000
# An error was encountered while fetching data from page 507. Status code = 422
# Retrieving page 508/1000
# An error was encountered while fetching data from page 508. Status code = 422
# Retrieving page 509/1000
# An error was encountered while fetching data from page 509. Status code = 422
# Retrieving page 510/1000
# An error was encountered while fetching data from page 510. Status code = 422
# Waiting for 2 seconds... There are currently 10000 movies IDs saved.
# Retrieving page 511/1000
# An error was encountered while fetching data from page 511. Status code = 422
# Retrieving page 512/1000
# An error was encountered while fetching data from page 512. Status code = 422
# Retrieving page 513/1000
# An error was encountered while fetching data from page 513. Status code = 422
# Retrieving page 514/1000
# An error was encountered while fetching data from page 514. Status code = 422
# Retrieving page 515/1000
# An error was encountered while fetching data from page 515. Status code = 422
# Retrieving page 516/1000
# An error was encountered while fetching data from page 516. Status code = 422
# Retrieving page 517/1000
# An error was encountered while fetching data from page 517. Status code = 422
# Retrieving page 518/1000
# An error was encountered while fetching data from page 518. Status code = 422
# Retrieving page 519/1000
# An error was encountered while fetching data from page 519. Status code = 422
# Retrieving page 520/1000
# An error was encountered while fetching data from page 520. Status code = 422
# Waiting for 2 seconds... There are currently 10000 movies IDs saved.
# Retrieving page 521/1000
# An error was encountered while fetching data from page 521. Status code = 422
# Retrieving page 522/1000
# An error was encountered while fetching data from page 522. Status code = 422
# Retrieving page 523/1000
# An error was encountered while fetching data from page 523. Status code = 422
# Retrieving page 524/1000
# An error was encountered while fetching data from page 524. Status code = 422
# Retrieving page 525/1000
# An error was encountered while fetching data from page 525. Status code = 422
# Retrieving page 526/1000
# An error was encountered while fetching data from page 526. Status code = 422
# Retrieving page 527/1000
# An error was encountered while fetching data from page 527. Status code = 422
# Retrieving page 528/1000
# An error was encountered while fetching data from page 528. Status code = 422
# Retrieving page 529/1000
# An error was encountered while fetching data from page 529. Status code = 422
# Retrieving page 530/1000
# An error was encountered while fetching data from page 530. Status code = 422
# Waiting for 2 seconds... There are currently 10000 movies IDs saved.
# Retrieving page 531/1000
# An error was encountered while fetching data from page 531. Status code = 422

# %% [markdown]
# Otrzymaliśmy w ten sposób 10000 numerów ID filmów. Zajrzyjmy jak one wyglądają.

# %%
print(movies_ids)
# Out:
# [603692, 502356, 569094, 385687, 890771, 447277, 667538, 879444, 713704, 640146, 1073140, 76600, 840326, 447365, 882569, 1018494, 1107872, 536437, 324857, 1098110, 594767, 799379, 758323, 1077321, 605886, 552688, 1115710, 893712, 1074178, 677179, 1070777, 620705, 315162, 943930, 934433, 1064517, 842675, 868759, 1105803, 1118203, 1094319, 493529, 420808, 634649, 916224, 981324, 298618, 505642, 995012, 8869, 948713, 436270, 977866, 1094403, 638974, 60898, 649609,
949423, 675445, 323260, 39254, 75338, 848058, 480530, 717930, 34433, 740952, 946700, 872516, 2322, 813726, 818397, 420634, 1018403, 1726, 98566, 404250, 527774, 155, 12, 588228, 298094, 271110, 312221, 39108, 10198, 141052, 131631, 425909, 1024546, 913673, 330457, 338947, 728754, 121, 424783, 18785, 1118721, 726366, 4935, 900667, 68726, 284052, 512195, 811656, 545611, 470044, 1098160, 11, 987578, 1013870, 10192, 379686, 8966, 705996, 1030613, 214756, 629176, 821890, 400160, 10020, 829165, 807, 607259, 801071, 259693, 928123, 829410, 744, 61979, 272878, 626872, 497698, 1047431, 603, 78 ...

# %% [markdown]
# Dzięki posiadaniu dokładnego numeru ID każdego filmu, jesteśmy w stanie zebrać jego wszystkie szczegółowe informacje przy jednorazowym zapytaniu. Pobierzmy je więc.

# %%
movies_data = []

movie_endpoint = "/movie/{movie_id}"
movie_params = {
    "api_key": "MY_API_KEY",
    "append_to_response": "reviews,credits",
}

for i in range(len(movies_ids)):
    movie_id = movies_ids[i]
    movie_url = f"{base_url}{movie_endpoint}".format(movie_id=movie_id)
    movie_response = requests.get(movie_url, params=movie_params)
    if movie_response.status_code == 200:
        movie_data = movie_response.json()
        movies_data.append(movie_data)
        if (i + 1) % 10 == 0:
            print(f"Downloaded already {i+1} movies details")
    elif response.status_code == 429:
        retry_after = int(response.headers.get("Retry-After"))
        print(f"Query limit exceeded. Waiting for {retry_after} seconds...")
        time.sleep(retry_after)
        i -= 1
    else:
        print(
            f"An error was encountered while fetching data for movie with ID {movie_id}). Status code = {response.status_code}"
        )
        errors_in_a_row += 1
        if errors_in_a_row > 30:
            break
    if (i + 1) % 500 == 0:
        wait_time = 2
        print(
            f"Waiting for {wait_time} seconds... There are currently {len(movies_data)} additional data saved."
        )
        time.sleep(wait_time)

print(f"Saved details of {len(movies_data)} movies")
# Out:
# Downloaded already 10 movies details
# Downloaded already 20 movies details
# Downloaded already 30 movies details
# Downloaded already 40 movies details
# Downloaded already 50 movies details
# Downloaded already 60 movies details
# Downloaded already 70 movies details
# Downloaded already 80 movies details
# Downloaded already 90 movies details
# Downloaded already 100 movies details
# Downloaded already 110 movies details
# Downloaded already 120 movies details
# Downloaded already 130 movies details
# Downloaded already 140 movies details
# Downloaded already 150 movies details
# Downloaded already 160 movies details
# Downloaded already 170 movies details
# Downloaded already 180 movies details
# Downloaded already 190 movies details
# Downloaded already 200 movies details
# Downloaded already 210 movies details
# Downloaded already 220 movies details
# Downloaded already 230 movies details
# Downloaded already 240 movies details
# Downloaded already 250 movies details
# Downloaded already 260 movies details
# Downloaded already 270 movies details
# Downloaded already 280 movies details
# Downloaded already 290 movies details
# Downloaded already 300 movies details
# Downloaded already 310 movies details
# Downloaded already 320 movies details
# Downloaded already 330 movies details
# Downloaded already 340 movies details
# Downloaded already 350 movies details
# Downloaded already 360 movies details
# Downloaded already 370 movies details
# Downloaded already 380 movies details
# Downloaded already 390 movies details
# Downloaded already 400 movies details
# Downloaded already 410 movies details
# Downloaded already 420 movies details
# Downloaded already 430 movies details
# Downloaded already 440 movies details
# Downloaded already 450 movies details
# Downloaded already 460 movies details
# Downloaded already 470 movies details
# Downloaded already 480 movies details
# Downloaded already 490 movies details
# Downloaded already 500 movies details
# Waiting for 2 seconds... There are currently 500 additional data saved.
# Downloaded already 510 movies details
# Downloaded already 520 movies details
# Downloaded already 530 movies details
# Downloaded already 540 movies details
# Downloaded already 550 movies details
# Downloaded already 560 movies details
# Downloaded already 570 movies details
# Downloaded already 580 movies details
# Downloaded already 590 movies details
# Downloaded already 600 movies details
# Downloaded already 610 movies details
# Downloaded already 620 movies details
# Downloaded already 630 movies details
# Downloaded already 640 movies details
# Downloaded already 650 movies details
# Downloaded already 660 movies details
# Downloaded already 670 movies details
# Downloaded already 680 movies details
# Downloaded already 690 movies details
# Downloaded already 700 movies details
# Downloaded already 710 movies details
# Downloaded already 720 movies details
# Downloaded already 730 movies details
# Downloaded already 740 movies details
# Downloaded already 750 movies details
# Downloaded already 760 movies details
# Downloaded already 770 movies details
# Downloaded already 780 movies details
# Downloaded already 790 movies details
# Downloaded already 800 movies details
# Downloaded already 810 movies details
# Downloaded already 820 movies details
# Downloaded already 830 movies details
# Downloaded already 840 movies details
# Downloaded already 850 movies details
# Downloaded already 860 movies details
# Downloaded already 870 movies details
# Downloaded already 880 movies details
# Downloaded already 890 movies details
# Downloaded already 900 movies details
# Downloaded already 910 movies details
# Downloaded already 920 movies details
# Downloaded already 930 movies details
# Downloaded already 940 movies details
# Downloaded already 950 movies details
# Downloaded already 960 movies details
# Downloaded already 970 movies details
# Downloaded already 980 movies details
# Downloaded already 990 movies details
# Downloaded already 1000 movies details
# Waiting for 2 seconds... There are currently 1000 additional data saved.
# Downloaded already 1010 movies details
# Downloaded already 1020 movies details
# Downloaded already 1030 movies details
# Downloaded already 1040 movies details
# Downloaded already 1050 movies details
# Downloaded already 1060 movies details
# Downloaded already 1070 movies details
# Downloaded already 1080 movies details
# Downloaded already 1090 movies details
# Downloaded already 1100 movies details
# Downloaded already 1110 movies details
# Downloaded already 1120 movies details
# Downloaded already 1130 movies details
# Downloaded already 1140 movies details
# Downloaded already 1150 movies details
# Downloaded already 1160 movies details
# Downloaded already 1170 movies details
# Downloaded already 1180 movies details
# Downloaded already 1190 movies details
# Downloaded already 1200 movies details
# Downloaded already 1210 movies details
# Downloaded already 1220 movies details
# Downloaded already 1230 movies details
# Downloaded already 1240 movies details
# Downloaded already 1250 movies details
# Downloaded already 1260 movies details
# Downloaded already 1270 movies details
# Downloaded already 1280 movies details
# Downloaded already 1290 movies details
# Downloaded already 1300 movies details
# Downloaded already 1310 movies details
# Downloaded already 1320 movies details
# Downloaded already 1330 movies details
# Downloaded already 1340 movies details
# Downloaded already 1350 movies details
# Downloaded already 1360 movies details
# Downloaded already 1370 movies details
# Downloaded already 1380 movies details
# Downloaded already 1390 movies details
# Downloaded already 1400 movies details
# Downloaded already 1410 movies details
# Downloaded already 1420 movies details
# Downloaded already 1430 movies details
# Downloaded already 1440 movies details
# Downloaded already 1450 movies details
# Downloaded already 1460 movies details
# Downloaded already 1470 movies details
# Downloaded already 1480 movies details
# Downloaded already 1490 movies details
# Downloaded already 1500 movies details
# Waiting for 2 seconds... There are currently 1500 additional data saved.
# Downloaded already 1510 movies details
# Downloaded already 1520 movies details
# Downloaded already 1530 movies details
# Downloaded already 1540 movies details
# Downloaded already 1550 movies details
# Downloaded already 1560 movies details
# Downloaded already 1570 movies details
# Downloaded already 1580 movies details
# Downloaded already 1590 movies details
# Downloaded already 1600 movies details
# Downloaded already 1610 movies details
# Downloaded already 1620 movies details
# Downloaded already 1630 movies details
# Downloaded already 1640 movies details
# Downloaded already 1650 movies details
# Downloaded already 1660 movies details
# Downloaded already 1670 movies details
# Downloaded already 1680 movies details
# Downloaded already 1690 movies details
# Downloaded already 1700 movies details
# Downloaded already 1710 movies details
# Downloaded already 1720 movies details
# Downloaded already 1730 movies details
# Downloaded already 1740 movies details
# Downloaded already 1750 movies details
# Downloaded already 1760 movies details
# Downloaded already 1770 movies details
# Downloaded already 1780 movies details
# Downloaded already 1790 movies details
# Downloaded already 1800 movies details
# Downloaded already 1810 movies details
# Downloaded already 1820 movies details
# Downloaded already 1830 movies details
# Downloaded already 1840 movies details
# Downloaded already 1850 movies details
# Downloaded already 1860 movies details
# Downloaded already 1870 movies details
# Downloaded already 1880 movies details
# Downloaded already 1890 movies details
# Downloaded already 1900 movies details
# Downloaded already 1910 movies details
# Downloaded already 1920 movies details
# Downloaded already 1930 movies details
# Downloaded already 1940 movies details
# Downloaded already 1950 movies details
# Downloaded already 1960 movies details
# Downloaded already 1970 movies details
# Downloaded already 1980 movies details
# Downloaded already 1990 movies details
# Downloaded already 2000 movies details
# Waiting for 2 seconds... There are currently 2000 additional data saved.
# Downloaded already 2010 movies details
# Downloaded already 2020 movies details
# Downloaded already 2030 movies details
# Downloaded already 2040 movies details
# Downloaded already 2050 movies details
# Downloaded already 2060 movies details
# Downloaded already 2070 movies details
# Downloaded already 2080 movies details
# Downloaded already 2090 movies details
# Downloaded already 2100 movies details
# Downloaded already 2110 movies details
# Downloaded already 2120 movies details
# Downloaded already 2130 movies details
# Downloaded already 2140 movies details
# Downloaded already 2150 movies details
# Downloaded already 2160 movies details
# Downloaded already 2170 movies details
# Downloaded already 2180 movies details
# Downloaded already 2190 movies details
# Downloaded already 2200 movies details
# Downloaded already 2210 movies details
# Downloaded already 2220 movies details
# Downloaded already 2230 movies details
# Downloaded already 2240 movies details
# Downloaded already 2250 movies details
# Downloaded already 2260 movies details
# Downloaded already 2270 movies details
# Downloaded already 2280 movies details
# Downloaded already 2290 movies details
# Downloaded already 2300 movies details
# Downloaded already 2310 movies details
# Downloaded already 2320 movies details
# Downloaded already 2330 movies details
# Downloaded already 2340 movies details
# Downloaded already 2350 movies details
# Downloaded already 2360 movies details
# Downloaded already 2370 movies details
# Downloaded already 2380 movies details
# Downloaded already 2390 movies details
# Downloaded already 2400 movies details
# Downloaded already 2410 movies details
# Downloaded already 2420 movies details
# Downloaded already 2430 movies details
# Downloaded already 2440 movies details
# Downloaded already 5400 movies details
# Downloaded already 5410 movies details
# Downloaded already 5420 movies details
# Downloaded already 5430 movies details
# Downloaded already 5440 movies details
# Downloaded already 5450 movies details
# Downloaded already 5460 movies details
# Downloaded already 5470 movies details
# Downloaded already 5480 movies details
# Downloaded already 5490 movies details
# Downloaded already 5500 movies details
# Waiting for 2 seconds... There are currently 5500 additional data saved.
# Downloaded already 5510 movies details
# Downloaded already 5520 movies details
# Downloaded already 5530 movies details
# Downloaded already 5540 movies details
# Downloaded already 5550 movies details
# Downloaded already 5560 movies details
# Downloaded already 5570 movies details
# Downloaded already 5580 movies details
# Downloaded already 5590 movies details
# Downloaded already 5600 movies details
# Downloaded already 5610 movies details
# Downloaded already 5620 movies details
# Downloaded already 5630 movies details
# Downloaded already 5640 movies details
# Downloaded already 5650 movies details
# Downloaded already 5660 movies details
# Downloaded already 5670 movies details
# Downloaded already 5680 movies details
# Downloaded already 5690 movies details
# Downloaded already 5700 movies details
# Downloaded already 5710 movies details
# Downloaded already 5720 movies details
# Downloaded already 5730 movies details
# Downloaded already 5740 movies details
# Downloaded already 5750 movies details
# Downloaded already 5760 movies details
# Downloaded already 5770 movies details
# Downloaded already 5780 movies details
# Downloaded already 5790 movies details
# Downloaded already 5800 movies details
# Downloaded already 5810 movies details
# Downloaded already 5820 movies details
# Downloaded already 5830 movies details
# Downloaded already 5840 movies details
# Downloaded already 5850 movies details
# Downloaded already 5860 movies details
# Downloaded already 5870 movies details
# Downloaded already 5880 movies details
# Downloaded already 5890 movies details
# Downloaded already 5900 movies details
# Downloaded already 5910 movies details
# Downloaded already 5920 movies details
# Downloaded already 5930 movies details
# Downloaded already 5940 movies details
# Downloaded already 5950 movies details
# Downloaded already 5960 movies details
# Downloaded already 5970 movies details
# Downloaded already 5980 movies details
# Downloaded already 5990 movies details
# Downloaded already 6000 movies details
# Waiting for 2 seconds... There are currently 6000 additional data saved.
# Downloaded already 6010 movies details
# Downloaded already 6020 movies details
# Downloaded already 6030 movies details
# Downloaded already 6040 movies details
# Downloaded already 6050 movies details
# Downloaded already 6060 movies details
# Downloaded already 6070 movies details
# Downloaded already 6080 movies details
# Downloaded already 6090 movies details
# Downloaded already 6100 movies details
# Downloaded already 6110 movies details
# Downloaded already 6120 movies details
# Downloaded already 6130 movies details
# Downloaded already 6140 movies details
# Downloaded already 6150 movies details
# Downloaded already 6160 movies details
# Downloaded already 6170 movies details
# Downloaded already 6180 movies details
# Downloaded already 6190 movies details
# Downloaded already 6200 movies details
# Downloaded already 6210 movies details
# Downloaded already 6220 movies details
# Downloaded already 6230 movies details
# Downloaded already 6240 movies details
# Downloaded already 6250 movies details
# Downloaded already 6260 movies details
# Downloaded already 6270 movies details
# Downloaded already 6280 movies details
# Downloaded already 6290 movies details
# Downloaded already 6300 movies details
# Downloaded already 6310 movies details
# Downloaded already 6320 movies details
# Downloaded already 6330 movies details
# Downloaded already 6340 movies details
# Downloaded already 6350 movies details
# Downloaded already 6360 movies details
# Downloaded already 6370 movies details
# Downloaded already 6380 movies details
# Downloaded already 6390 movies details
# Downloaded already 6400 movies details
# Downloaded already 6410 movies details
# Downloaded already 6420 movies details
# Downloaded already 6430 movies details
# Downloaded already 6440 movies details
# Downloaded already 6450 movies details
# Downloaded already 6460 movies details
# Downloaded already 6470 movies details
# Downloaded already 6480 movies details
# Downloaded already 6490 movies details
# Downloaded already 6500 movies details
# Waiting for 2 seconds... There are currently 6500 additional data saved.
# Downloaded already 6510 movies details
# Downloaded already 6520 movies details
# Downloaded already 6530 movies details
# Downloaded already 6540 movies details
# Downloaded already 6550 movies details
# Downloaded already 6560 movies details
# Downloaded already 6570 movies details
# Downloaded already 6580 movies details
# Downloaded already 6590 movies details
# Downloaded already 6600 movies details
# Downloaded already 6610 movies details
# Downloaded already 6620 movies details
# Downloaded already 6630 movies details
# Downloaded already 6640 movies details
# Downloaded already 6650 movies details
# Downloaded already 6660 movies details
# Downloaded already 6670 movies details
# Downloaded already 6680 movies details
# Downloaded already 6690 movies details
# Downloaded already 6700 movies details
# Downloaded already 6710 movies details
# Downloaded already 6720 movies details
# Downloaded already 6730 movies details
# Downloaded already 6740 movies details
# Downloaded already 6750 movies details
# Downloaded already 6760 movies details
# Downloaded already 6770 movies details
# Downloaded already 6780 movies details
# Downloaded already 6790 movies details
# Downloaded already 6800 movies details
# Downloaded already 6810 movies details
# Downloaded already 6820 movies details
# Downloaded already 6830 movies details
# Downloaded already 6840 movies details
# Downloaded already 6850 movies details
# Downloaded already 6860 movies details
# Downloaded already 6870 movies details
# Downloaded already 6880 movies details
# Downloaded already 6890 movies details
# Downloaded already 6900 movies details
# Downloaded already 6910 movies details
# Downloaded already 6920 movies details
# Downloaded already 6930 movies details
# Downloaded already 6940 movies details
# Downloaded already 6950 movies details
# Downloaded already 6960 movies details
# Downloaded already 6970 movies details
# Downloaded already 6980 movies details
# Downloaded already 6990 movies details
# Downloaded already 7000 movies details
# Waiting for 2 seconds... There are currently 7000 additional data saved.
# Downloaded already 7010 movies details
# Downloaded already 7020 movies details
# Downloaded already 7030 movies details
# Downloaded already 7040 movies details
# Downloaded already 7050 movies details
# Downloaded already 7060 movies details
# Downloaded already 7070 movies details
# Downloaded already 7080 movies details
# Downloaded already 7090 movies details
# Downloaded already 7100 movies details
# Downloaded already 7110 movies details
# Downloaded already 7120 movies details
# Downloaded already 7130 movies details
# Downloaded already 7140 movies details
# Downloaded already 7150 movies details
# Downloaded already 7160 movies details
# Downloaded already 7170 movies details
# Downloaded already 7180 movies details
# Downloaded already 7190 movies details
# Downloaded already 7200 movies details
# Downloaded already 7210 movies details
# Downloaded already 7220 movies details
# Downloaded already 7230 movies details
# Downloaded already 7240 movies details
# Downloaded already 7250 movies details
# Downloaded already 7260 movies details
# Downloaded already 7270 movies details
# Downloaded already 7280 movies details
# Downloaded already 7290 movies details
# Downloaded already 7300 movies details
# Downloaded already 7310 movies details
# Downloaded already 7320 movies details
# Downloaded already 7330 movies details
# Downloaded already 7340 movies details
# Downloaded already 7350 movies details
# Downloaded already 7360 movies details
# Downloaded already 7370 movies details
# Downloaded already 7380 movies details
# Downloaded already 7390 movies details
# Downloaded already 7400 movies details
# Downloaded already 7410 movies details
# Downloaded already 7420 movies details
# Downloaded already 7430 movies details
# Downloaded already 7440 movies details
# Downloaded already 7450 movies details
# Downloaded already 7460 movies details
# Downloaded already 7470 movies details
# Downloaded already 7480 movies details
# Downloaded already 7490 movies details
# Downloaded already 7500 movies details
# Waiting for 2 seconds... There are currently 7500 additional data saved.
# Downloaded already 7510 movies details
# Downloaded already 7520 movies details
# Downloaded already 7530 movies details
# Downloaded already 7540 movies details
# Downloaded already 7550 movies details
# Downloaded already 7560 movies details
# Downloaded already 7570 movies details
# Downloaded already 7580 movies details
# Downloaded already 7590 movies details
# Downloaded already 7600 movies details
# Downloaded already 7610 movies details
# Downloaded already 7620 movies details
# Downloaded already 7630 movies details
# Downloaded already 7640 movies details
# Downloaded already 7650 movies details
# Downloaded already 7660 movies details
# Downloaded already 7670 movies details
# Downloaded already 7680 movies details
# Downloaded already 7690 movies details
# Downloaded already 7700 movies details
# Downloaded already 7710 movies details
# Downloaded already 7720 movies details
# Downloaded already 7730 movies details
# Downloaded already 7740 movies details
# Downloaded already 7750 movies details
# Downloaded already 7760 movies details
# Downloaded already 7770 movies details
# Downloaded already 7780 movies details
# Downloaded already 7790 movies details
# Downloaded already 7800 movies details
# Downloaded already 7810 movies details
# Downloaded already 7820 movies details
# Downloaded already 7830 movies details
# Downloaded already 7840 movies details
# Downloaded already 7850 movies details
# Downloaded already 7860 movies details
# Downloaded already 7870 movies details
# Downloaded already 7880 movies details
# Downloaded already 7890 movies details
# Downloaded already 7900 movies details
# Downloaded already 7910 movies details
# Downloaded already 7920 movies details
# Downloaded already 7930 movies details
# Downloaded already 7940 movies details
# Downloaded already 7950 movies details
# Downloaded already 7960 movies details
# Downloaded already 7970 movies details
# Downloaded already 7980 movies details
# Downloaded already 7990 movies details
# Downloaded already 8000 movies details
# Waiting for 2 seconds... There are currently 8000 additional data saved.
# Downloaded already 8010 movies details
# Downloaded already 8020 movies details
# Downloaded already 8030 movies details
# Downloaded already 8040 movies details
# Downloaded already 8050 movies details
# Downloaded already 8060 movies details
# Downloaded already 8070 movies details
# Downloaded already 8080 movies details
# Downloaded already 8090 movies details
# Downloaded already 8100 movies details
# Downloaded already 8110 movies details
# Downloaded already 8120 movies details
# Downloaded already 8130 movies details
# Downloaded already 8140 movies details
# Downloaded already 8150 movies details
# Downloaded already 8160 movies details
# Downloaded already 8170 movies details
# Downloaded already 8180 movies details
# Downloaded already 8190 movies details
# Downloaded already 8200 movies details
# Downloaded already 8210 movies details
# Downloaded already 8220 movies details
# Downloaded already 8230 movies details
# Downloaded already 8240 movies details
# Downloaded already 8250 movies details
# Downloaded already 8260 movies details
# Downloaded already 8270 movies details
# Downloaded already 8280 movies details
# Downloaded already 8290 movies details
# Downloaded already 8300 movies details
# Downloaded already 8310 movies details
# Downloaded already 8320 movies details
# Downloaded already 8330 movies details
# Downloaded already 8340 movies details
# Downloaded already 8350 movies details
# Downloaded already 9350 movies details
# Downloaded already 9360 movies details
# Downloaded already 9370 movies details
# Downloaded already 9380 movies details
# Downloaded already 9390 movies details
# Downloaded already 9400 movies details
# Downloaded already 9410 movies details
# Downloaded already 9420 movies details
# Downloaded already 9430 movies details
# Downloaded already 9440 movies details
# Downloaded already 9450 movies details
# Downloaded already 9460 movies details
# Downloaded already 9470 movies details
# Downloaded already 9480 movies details
# Downloaded already 9490 movies details
# Downloaded already 9500 movies details
# Waiting for 2 seconds... There are currently 9500 additional data saved.
# Downloaded already 9510 movies details
# Downloaded already 9520 movies details
# Downloaded already 9530 movies details
# Downloaded already 9540 movies details
# Downloaded already 9550 movies details
# Downloaded already 9560 movies details
# Downloaded already 9570 movies details
# Downloaded already 9580 movies details
# Downloaded already 9590 movies details
# Downloaded already 9600 movies details
# Downloaded already 9610 movies details
# Downloaded already 9620 movies details
# Downloaded already 9630 movies details
# Downloaded already 9640 movies details
# Downloaded already 9650 movies details
# Downloaded already 9660 movies details
# Downloaded already 9670 movies details
# Downloaded already 9680 movies details
# Downloaded already 9690 movies details
# Downloaded already 9700 movies details
# Downloaded already 9710 movies details
# Downloaded already 9720 movies details
# Downloaded already 9730 movies details
# Downloaded already 9740 movies details
# Downloaded already 9750 movies details
# Downloaded already 9760 movies details
# Downloaded already 9770 movies details
# Downloaded already 9780 movies details
# Downloaded already 9790 movies details
# Downloaded already 9800 movies details
# Downloaded already 9810 movies details
# Downloaded already 9820 movies details
# Downloaded already 9830 movies details
# Downloaded already 9840 movies details
# Downloaded already 9850 movies details
# Downloaded already 9860 movies details
# Downloaded already 9870 movies details
# Downloaded already 9880 movies details
# Downloaded already 9890 movies details
# Downloaded already 9900 movies details
# Downloaded already 9910 movies details
# Downloaded already 9920 movies details
# Downloaded already 9930 movies details
# Downloaded already 9940 movies details
# Downloaded already 9950 movies details
# Downloaded already 9960 movies details
# Downloaded already 9970 movies details
# Downloaded already 9980 movies details
# Downloaded already 9990 movies details
# Downloaded already 10000 movies details
# Waiting for 2 seconds... There are currently 10000 additional data saved.
# Saved details of 10000 movies

# %% [markdown]
# Sprawdźmy jak wyglądają pobrane dane:

# %%
print(movies_data[0])
print(movies_data[1])
print(movies_data[2])
# Out:
# {'adult': False, 'backdrop_path': '/h8gHn0OzBoaefsYseUByqsmEDMY.jpg', 'belongs_to_collection': {'id': 404609, 'name': 'John Wick Collection', 'poster_path': '/xUidyvYFsbbuExifLkslpcd8SMc.jpg', 'backdrop_path': '/fSwYa5q2xRkBoOOjueLpkLf3N1m.jpg'}, 'budget': 90000000, 'genres': [{'id': 28, 'name': 'Action'}, {'id': 53, 'name': 'Thriller'}, {'id': 80, 'name': 'Crime'}], 'homepage': 'https://johnwick.movie', 'id': 603692, 'imdb_id': 'tt10366206', 'original_language': 'en', 'original_title': 'John Wick: Chapter 4', 'overview': 'With the price on his head ever increasing, John Wick uncovers a path to defeating The High Table. But before he can earn his freedom, Wick must face off against a new enemy with powerful alliances across the globe and forces that turn old friends into foes.', 'popularity': 4071.868, 'poster_path': '/vZloFAK7NmvMGKE7VkF5UHaz0I.jpg', 'production_companies': [{'id': 3528, 'logo_path': '/cCzCClIzIh81Fa79hpW5nXoUsHK.png', 'name': 'Thunder Road', 'origin_country': 'US'}, {'id': 23008, 'logo_path': '/5SarYupipdiejsEqUkwu1SpYfru.png', 'name': '87Eleven', 'origin_country': 'US'}, {'id': 491, 'logo_path': '/5LvDUt3KmvRnXQ4NrdWJYHeuA8J.png', 'name': 'Summit Entertainment', 'origin_country': 'US'}, {'id': 264, 'logo_path': '/fA90qwUKgPhMONqtwY60GaHRyrW.png', 'name': 'Studio Babelsberg', 'origin_country': 'DE'}], 'production_countries': [{'iso_3166_1': 'DE', 'name': 'Germany'}, {'iso_3166_1': 'US', 'name': 'United States of America'}], 'release_date': '2023-03-22', 'revenue': 431769198, 'runtime': 170, 'spoken_languages': [{'english_name': 'Arabic', 'iso_639_1': 'ar', 'name': 'العربية'}, {'english_name': 'Cantonese', 'iso_639_1': 'cn', 'name': '广州话 / 廣州話'}, {'english_name': 'English', 'iso_639_1': 'en', 'name': 'English'}, {'english_name': 'French', 'iso_639_1': 'fr', 'name': 'Français'}, {'english_name': 'German', 'iso_639_1': 'de', 'name': 'Deutsch'}, {'english_name': 'Japanese', 'iso_639_1': 'ja', 'name': '日本語'}, {'english_name': 'Latin', 'iso_639_1': 'la', 'name': 'Latin'}, {'english_name': 'Russian', 'iso_639_1': 'ru', 'name': 'Pусский'}, {'english_name': 'Spanish', 'iso_639_1': 'es', 'name': 'Español'}], 'status': 'Released', 'tagline': 'No way back, one way out.', 'title': 'John Wick: Chapter 4', 'video': False, 'vote_average': 7.95, 'vote_count': 2763, 'reviews': {'page': 1, 'results': [{'author': 'thealanfrench', 'author_details': {'name': '', 'username': 'thealanfrench', 'avatar_path': '/https://secure.gravatar.com/avatar/23f2cd16e6fafdf013b30ccc22e2e4c8.jpg', 'rating': None}, 'content': 'Check out the full spoiler free review at Sunshine State Cineplex. \r\nhttps://sunshinestatecineplex.com/2023/03/13/sxsw-2023-john-wick-chapter-4-2023/\r\n\r\nJohn Wick: Chapter 4 might be a little long, but when it is fun, there are few films that can compete with its magnetism. Reeves shows why he’s one of the best genre actors in the world and pours his heart and soul into a soft-spoken performance. Combined with Stahelski’s fight sequences, this is sure to become a highly rewatched, often quoted classic.', 'created_at': '2023-03-15T05:13:49.138Z', 'id': '6411540dfe6c1800bb659ebd', 'updated_at': '2023-03-24T22:19:13.344Z', 'url': 'https://www.themoviedb.org/review/6411540dfe6c1800bb659ebd'}, {'author': 'romang', 'author_details': {'name': '', 'username': 'romang', 'avatar_path': '/https://secure.gravatar.com/avatar/5bfcd882a57748ce30d3e9caea9f9c44.jpg', 'rating': 4.0}, 'content': 'Good movie!', 'created_at': '2023-03-22T09:48:42.089Z', 'id': '641acefa95c0af0084eb0d5d', 'updated_at': '2023-03-24T22:24:12.645Z', 'url': 'https://www.themoviedb.org/review/641acefa95c0af0084eb0d5d'}, {'author': 'The Movie Mob', 'author_details': {'name': 'The Movie Mob', 'username': 'mooney240', 'avatar_path': '/blEC280vq31MVaDcsWBXuGOsYnB.jpg', 'rating': 9.0}, 'content': '**John Wick: Chapter 4 is at the peak of action cinema and fight choreography. What the film lacks in story is dramatically overcome with the most stunning action set pieces  ...
# {'adult': False, 'backdrop_path': '/2klQ1z1fcHGgQPevbEQdkCnzyuS.jpg', 'belongs_to_collection': None, 'budget': 100000000, 'genres': [{'id': 16, 'name': 'Animation'}, {'id': 10751, 'name': 'Family'}, {'id': 12, 'name': 'Adventure'}, {'id': 14, 'name': 'Fantasy'}, {'id': 35, 'name': 'Comedy'}], 'homepage': 'https://www.thesupermariobros.movie', 'id': 502356, 'imdb_id': 'tt6718170', 'original_language': 'en', 'original_title': 'The Super Mario Bros. Movie', 'overview': 'While working underground to fix a water main, Brooklyn plumbers—and brothers—Mario and Luigi are transported down a mysterious pipe and wander into a magical new world. But when the brothers are separated, Mario embarks on an epic quest to find Luigi.', 'popularity': 3054.106, 'poster_path': '/qNBAXBIQlnOThrVvA6mA2B5ggV6.jpg', 'production_companies': [{'id': 33, 'logo_path': '/8lvHyhjr8oUKOOy2dKXoALWKdp0.png', 'name': 'Universal Pictures', 'origin_country': 'US'}, {'id': 6704, 'logo_path': '/fOG2oY4m1YuYTQh4bMqqZkmgOAI.png', 'name': 'Illumination', 'origin_country': 'US'}, {'id': 12288, 'logo_path': '/e4dQAqZD374H5EuM0W1ljEBWTKy.png', 'name': 'Nintendo', 'origin_country': 'JP'}], 'production_countries': [{'iso_3166_1': 'JP', 'name': 'Japan'}, {'iso_3166_1': 'US', 'name': 'United States of America'}], 'release_date': '2023-04-05', 'revenue': 1308766975, 'runtime': 92, 'spoken_languages': [{'english_name': 'English', 'iso_639_1': 'en', 'name': 'English'}], 'status': 'Released', 'tagline': '', 'title': 'The Super Mario Bros. Movie', 'video': False, 'vote_average': 7.8, 'vote_count': 4459, 'reviews': {'page': 1, 'results': [{'author': 'Chris Sawin', 'author_details': {'name': 'Chris Sawin', 'username': 'ChrisSawin', 'avatar_path': '/https://secure.gravatar.com/avatar/bf3b87ecb40599290d764e6d73c86319.jpg', 'rating': 5.0}, 'content': '_The Super Mario Bros. Movie_ is like Fruit Stripe Gum. It’s super colorful and eyecatching, but it seems to instantly lose its flavor and charm. The film is visually stunning and Jack Black is outstanding as Bowser. The big action sequences are like big budget versions of the Mario video games playthroughs with little welcome surprises thrown in.\r\n\r\nBut the film is massively unfunny, the characters are extremely flat, and the flimsy writing is about as complex as an unkempt mustache.\r\n\r\n**Full review:** https://boundingintocomics.com/2023/04/06/the-super-mario-bros-movie-review-plunging-rainbow-colored-nostalgia-to-death/', 'created_at': '2023-04-06T20:38:59.988Z', 'id': '642f2de32588230098248468', 'updated_at': '2023-04-06T20:39:00.115Z', 'url': 'https://www.themoviedb.org/review/642f2de32588230098248468'}, {'author': 'CinemaSerf', 'author_details': {'name': 'CinemaSerf', 'username': 'Geronimo1967', 'avatar_path': '/1kks3YnVkpyQxzw36CObFPvhL5f.jpg', 'rating': 6.0}, 'content': 'I am not the demographic and to be honest this isn\'t really a film that I was ever going to like either. The story is beyond simple and the game-based animation - though expertly crafted - did absolutely nothing for me as ninety minutes rolled along devoid of characterisations, thrill or much sense of adventure. I got the feeling this was really an outing for "Mario", "Luigi" and "Peach" designed to satisfy the die-hard fans, or the children - or both, but if you were not in on the game from the start then you are unlikely to have become any more engaged by the end of this fungi-fest. It wouldn\'t be fair to say this is bland - it\'s not designed to challenge or take risks: it\'s fun for those who grew up with "Mario" et al in their lives and I\'m not going to decry that. It\'s colourful, pacy, and at times quite well written but perhaps it ought to have a rating that says if you are over 12 then you should be advised against it?', 'created_at': '2023-04-13T13:19:08.627Z', 'id': '6438014c1d538600f40f4d4e', 'updated_at': '2023-04-13T13:19:08.722Z', 'url': 'https://www.themoviedb.org/review/6438014c1d538600f40f4d4e'}, {'author': 'MSB', 'author_details': {'n ...
# {'adult': False, 'backdrop_path': '/2I5eBh98Q4aPq8WdQrHdTC8ARhY.jpg', 'belongs_to_collection': {'id': 573436, 'name': 'Spider-Man: Spider-Verse Collection', 'poster_path': '/eD4bGQNfmqExIAzKdvX5gDHhI2.jpg', 'backdrop_path': '/14F6gMaRjzgsN6EEpiwH87R1I00.jpg'}, 'budget': 100000000, 'genres': [{'id': 28, 'name': 'Action'}, {'id': 12, 'name': 'Adventure'}, {'id': 16, 'name': 'Animation'}, {'id': 878, 'name': 'Science Fiction'}], 'homepage': 'https://www.acrossthespiderverse.movie', 'id': 569094, 'imdb_id': 'tt9362722', 'original_language': 'en', 'original_title': 'Spider-Man: Across the Spider-Verse', 'overview': 'After reuniting with Gwen Stacy, Brooklyn’s full-time, friendly neighborhood Spider-Man is catapulted across the Multiverse, where he encounters the Spider Society, a team of Spider-People charged with protecting the Multiverse’s very existence. But when the heroes clash on how to handle a new threat, Miles finds himself pitted against the other Spiders and must set out on his own to save those he loves most.', 'popularity': 2860.755, 'poster_path': '/8Vt6mWEReuy4Of61Lnj5Xj704m8.jpg', 'production_companies': [{'id': 5, 'logo_path': '/71BqEFAF4V3qjjMPCpLuyJFB9A.png', 'name': 'Columbia Pictures', 'origin_country': 'US'}, {'id': 2251, 'logo_path': '/5ilV5mH3gxTEU7p5wjxptHvXkyr.png', 'name': 'Sony Pictures Animation', 'origin_country': 'US'}, {'id': 7505, 'logo_path': '/837VMM4wOkODc1idNxGT0KQJlej.png', 'name': 'Marvel Entertainment', 'origin_country': 'US'}, {'id': 77973, 'logo_path': '/9y5lW86HnxKUZOFencYk3TIIRCM.png', 'name': 'Lord Miller', 'origin_country': 'US'}, {'id': 84041, 'logo_path': '/nw4kyc29QRpNtFbdsBHkRSFavvt.png', 'name': 'Pascal Pictures', 'origin_country': 'US'}, {'id': 166230, 'logo_path': None, 'name': 'Avi Arad Productions', 'origin_country': 'US'}], 'production_countries': [{'iso_3166_1': 'US', 'name': 'United States of America'}], 'release_date': '2023-05-31', 'revenue': 221579351, 'runtime': 140, 'spoken_languages': [{'english_name': 'English', 'iso_639_1': 'en', 'name': 'English'}, {'english_name': 'Hindi', 'iso_639_1': 'hi', 'name': 'हिन्दी'}, {'english_name': 'Italian', 'iso_639_1': 'it', 'name': 'Italiano'}, {'english_name': 'Spanish', 'iso_639_1': 'es', 'name': 'Español'}], 'status': 'Released', 'tagline': "It's how you wear the mask that matters", 'title': 'Spider-Man: Across the Spider-Verse', 'video': False, 'vote_average': 8.802, 'vote_count': 935, 'reviews': {'page': 1, 'results': [{'author': 'garethmb', 'author_details': {'name': '', 'username': 'garethmb', 'avatar_path': '/https://secure.gravatar.com/avatar/3593437cbd05cebe0a4ee753965a8ad1.jpg', 'rating': None}, 'content': 'Life as a teenager is never easy and when you are gifted with the superhuman abilities of a spider and lead a double life as a student and crime fighter; life gets even harder.\r\n\r\nMiles Morales (Shameik Moore) is finding it even harder to hide his secret from his family who has grown concerned that his erratic behavior is more than the usual teenage angst.\r\n\r\nIn another earth, Gwen Stacy (Hailee Steinfeld) deals with her Police officer father desperately hunting down her alter-ego believing that she is a killer which drives a wedge between them as Gwen desperately tries to find her way forward.\r\n\r\nIn “Spider-Man Across the Spider-Verse audiences learn that what one perceives as reality is often just the corner of a much larger picture and when Miles confronts what he dismisses as a “Villain of the Week” in a quirky enemy known as The Spot (Jason Schwartzman), starts a campaign against Spider-Man, he soon finds that the threat is much larger than he expected and secretly follows a visiting Gwen into an another Earth where his actions soon draw the attention of a larger temporal Spider squad.\r\n\r\nMotivated by his feelings for Gwen and a desire to do good, Miles looks to undo the damage that the Spot is causing across various Earths and learns that each one has its own version of Spider-man or Woman to prot ...

# %% [markdown]
# Mamy już wszystkie potrzebne dane w nieco chaotycznej jeszcze formie, ale zajmiemy się tym podczas preprocessingu. Póki co zapiszmy nasze dane do pliku CSV.

# %%
# Zapisywanie danych do pliku CSV
with open("movies_data.csv", mode="w", newline="", encoding="utf-8") as file:
    writer = csv.DictWriter(file, fieldnames=movies_data[0].keys())
    writer.writeheader()
    writer.writerows(movies_data)

print(f"Saved {len(movies_data)} movies to movies.csv")
# Out:
# Saved 10000 movies to movies.csv
